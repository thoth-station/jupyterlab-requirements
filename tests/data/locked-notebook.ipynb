# %%
# %horus requirements --add boto3
# Out:
# '{"packages": {"boto3": "*"}, "dev-packages": {}, "source": [{"url": "https://pypi.org/simple", "verify_ssl": true, "name": "pypi"}], "requires": {"python_version": "3.8"}}'

# %%
# %horus lock --os-name ubi --os-version 8 --kernel-name jl-test
# Out:
# Using '/home/fmurdaca/.local/share/thoth/kernels' as project root directory
# Using '/home/fmurdaca/.local/share/thoth/kernels' as project root directory
#                                  Application stack guidance
#                                         ╷                                       ╷
#   Link                                  │ Message                               │ Type
#  ═══════════════════════════════════════╪═══════════════════════════════════════╪═══════════
#   ]8;id=169363;https://thoth-station.ninja/j/cve_timestamp\https://thoth-station.ninja/j/cve_tim]8;;\ │ CVE database of known vulnerabilities │ ✔️ INFO
#   ]8;id=169363;https://thoth-station.ninja/j/cve_timestamp\estamp]8;;\                                │ for Python packages was updated at    │
#                                         │ '2021-11-26T00:00:03.946189'          │
# ...
